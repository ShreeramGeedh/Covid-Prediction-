# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import DenseNet121
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Data

# %%
disease_types=['COVID', 'non-COVID']
data_dir = '/kaggle/input/sarscov2-ctscan-dataset/SARS-Cov-2/'
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.head()
# Out:
#                     File  DiseaseID Disease Type
# 0  COVID/Covid (241).png          0        COVID
# 1  COVID/Covid (216).png          0        COVID
# 2  COVID/Covid (983).png          0        COVID
# 3   COVID/Covid (99).png          0        COVID
# 4  COVID/Covid (251).png          0        COVID

# %% [markdown]
# ## Randomize the order of training set

# %%
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                              File  DiseaseID Disease Type
# 0           COVID/Covid (841).png          0        COVID
# 1           COVID/Covid (510).png          0        COVID
# 2  non-COVID/Non-Covid (1153).png          1    non-COVID
# 3   non-COVID/Non-Covid (659).png          1    non-COVID
# 4           COVID/Covid (888).png          0        COVID

# %% [markdown]
# ## Plot a histogram

# %%
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %% [markdown]
# ## Display images of COVID

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('COVID', 5, 5)

# %% [markdown]
# ## Display images of non-COVID

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('non-COVID', 5, 5)

# %% [markdown]
# ## Image Read and Resize Function

# %%
IMAGE_SIZE = 64
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %% [markdown]
# ## Training Images

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 2482it [00:15, 165.10it/s]
# Train Shape: (2482, 64, 64, 3)

# %% [markdown]
# ## Converting Labels to Categorical

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)

# %% [markdown]
# ## Train Test Splitting

# %%
BATCH_SIZE = 64

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %% [markdown]
# ## 64*64 training images

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 50
SIZE=64
N_ch=3

# %% [markdown]
# ## DenseNet121 Model

# %%
def build_densenet():
    densenet = DenseNet121(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %% [markdown]
# ## Data Augmentation and Fitting Model

# %%
model = build_densenet()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 3)         84
# _________________________________________________________________
# densenet121 (Model)          multiple                  7037504
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 2)                 514
# =================================================================
# Total params: 7,305,622
# Trainable params: 7,219,414
# Non-trainable params: 86,208
# _________________________________________________________________
# Epoch 1/50
#  - 79s - loss: 1.1782 - accuracy: 0.5435 - val_loss: 0.7166 - val_accuracy: 0.5936
#
# Epoch 00001: val_loss improved from inf to 0.71657, saving model to model.h5
# Epoch 2/50
#  - 8s - loss: 0.9714 - accuracy: 0.6080 - val_loss: 0.7021 - val_accuracy: 0.5654
#
# Epoch 00002: val_loss improved from 0.71657 to 0.70212, saving model to model.h5
# Epoch 3/50
#  - 8s - loss: 0.8752 - accuracy: 0.6569 - val_loss: 0.7020 - val_accuracy: 0.5533
#
# Epoch 00003: val_loss improved from 0.70212 to 0.70199, saving model to model.h5
# Epoch 4/50
#  - 8s - loss: 0.7654 - accuracy: 0.6746 - val_loss: 0.6817 - val_accuracy: 0.6157
#
# Epoch 00004: val_loss improved from 0.70199 to 0.68167, saving model to model.h5
# Epoch 5/50
#  - 8s - loss: 0.7262 - accuracy: 0.6991 - val_loss: 3.5254 - val_accuracy: 0.4809
#
# Epoch 00005: val_loss did not improve from 0.68167
# Epoch 6/50
#  - 8s - loss: 0.6796 - accuracy: 0.7169 - val_loss: 2.2210 - val_accuracy: 0.5131
#
# Epoch 00006: val_loss did not improve from 0.68167
# Epoch 7/50
#  - 9s - loss: 0.6105 - accuracy: 0.7394 - val_loss: 1.2013 - val_accuracy: 0.5855
#
# Epoch 00007: val_loss did not improve from 0.68167
# Epoch 8/50
#  - 8s - loss: 0.5972 - accuracy: 0.7449 - val_loss: 1.0661 - val_accuracy: 0.6097
#
# Epoch 00008: val_loss did not improve from 0.68167
# Epoch 9/50
#  - 8s - loss: 0.5511 - accuracy: 0.7761 - val_loss: 0.7804 - val_accuracy: 0.6720
#
# Epoch 00009: val_loss did not improve from 0.68167
# Epoch 10/50
#  - 8s - loss: 0.5275 - accuracy: 0.7757 - val_loss: 0.8670 - val_accuracy: 0.6439
#
# Epoch 00010: val_loss did not improve from 0.68167
# Epoch 11/50
#  - 8s - loss: 0.4715 - accuracy: 0.8057 - val_loss: 0.9651 - val_accuracy: 0.6358
#
# Epoch 00011: val_loss did not improve from 0.68167
# Epoch 12/50
#  - 8s - loss: 0.4457 - accuracy: 0.8162 - val_loss: 0.8170 - val_accuracy: 0.6700
#
# Epoch 00012: val_loss did not improve from 0.68167
# Epoch 13/50
#  - 8s - loss: 0.4289 - accuracy: 0.8342 - val_loss: 0.4473 - val_accuracy: 0.7968
#
# Epoch 00013: val_loss improved from 0.68167 to 0.44731, saving model to model.h5
# Epoch 14/50
#  - 9s - loss: 0.4605 - accuracy: 0.8192 - val_loss: 0.3207 - val_accuracy: 0.8592
#
# Epoch 00014: val_loss improved from 0.44731 to 0.32069, saving model to model.h5
# Epoch 15/50
#  - 8s - loss: 0.4093 - accuracy: 0.8327 - val_loss: 0.5399 - val_accuracy: 0.7746
#
# Epoch 00015: val_loss did not improve from 0.32069
# Epoch 16/50
#  - 8s - loss: 0.3927 - accuracy: 0.8350 - val_loss: 0.4297 - val_accuracy: 0.7988
#
# Epoch 00016: val_loss did not improve from 0.32069
# Epoch 17/50
#  - 8s - loss: 0.3893 - accuracy: 0.8466 - val_loss: 0.2630 - val_accuracy: 0.8934
#
# Epoch 00017: val_loss improved from 0.32069 to 0.26297, saving model to model.h5
# Epoch 18/50
#  - 8s - loss: 0.3646 - accuracy: 0.8621 - val_loss: 0.5510 - val_accuracy: 0.7324
#
# Epoch 00018: val_loss did not improve from 0.26297
# Epoch 19/50
#  - 8s - loss: 0.3707 - accuracy: 0.8478 - val_loss: 0.5863 - val_accuracy: 0.7143
#
# Epoch 00019: val_loss did not improve from 0.26297
# Epoch 20/50
#  - 8s - loss: 0.3454 - accuracy: 0.8644 - val_loss: 0.4938 - val_accuracy: 0.7223
#
# Epoch 00020: val_loss did not improve from 0.26297
# Epoch 21/50
#  - 9s - loss: 0.3329 - accuracy: 0.8636 - val_loss: 0.3086 - val_accuracy: 0.8511
#
# Epoch 00021: val_loss did not improve from 0.26297
# Epoch 22/50
#  - 8s - loss: 0.3505 - accuracy: 0.8503 - val_loss: 0.3194 - val_accuracy: 0.8692
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 00022: val_loss did not improve from 0.26297
# Epoch 23/50
#  - 8s - loss: 0.3412 - accuracy: 0.8636 - val_loss: 0.2965 - val_accuracy: 0.8753
#
# Epoch 00023: val_loss did not improve from 0.26297
# Epoch 24/50
#  - 8s - loss: 0.3165 - accuracy: 0.8709 - val_loss: 0.2532 - val_accuracy: 0.9014
#
# Epoch 00024: val_loss improved from 0.26297 to 0.25320, saving model to model.h5
# Epoch 25/50
#  - 22s - loss: 0.3180 - accuracy: 0.8794 - val_loss: 0.3066 - val_accuracy: 0.8511
#
# Epoch 00025: val_loss did not improve from 0.25320
# Epoch 26/50
#  - 9s - loss: 0.3090 - accuracy: 0.8700 - val_loss: 0.2390 - val_accuracy: 0.8974
#
# Epoch 00026: val_loss improved from 0.25320 to 0.23901, saving model to model.h5
# Epoch 27/50
#  - 8s - loss: 0.3219 - accuracy: 0.8787 - val_loss: 0.2301 - val_accuracy: 0.9095
#
# Epoch 00027: val_loss improved from 0.23901 to 0.23012, saving model to model.h5
# Epoch 28/50
#  - 8s - loss: 0.3084 - accuracy: 0.8813 - val_loss: 0.2395 - val_accuracy: 0.8974
#
# Epoch 00028: val_loss did not improve from 0.23012
# Epoch 29/50
#  - 8s - loss: 0.3259 - accuracy: 0.8766 - val_loss: 0.2767 - val_accuracy: 0.8773
#
# Epoch 00029: val_loss did not improve from 0.23012
# Epoch 30/50
#  - 8s - loss: 0.3062 - accuracy: 0.8886 - val_loss: 0.3819 - val_accuracy: 0.8109
#
# Epoch 00030: val_loss did not improve from 0.23012
# Epoch 31/50
#  - 8s - loss: 0.2770 - accuracy: 0.8906 - val_loss: 0.2729 - val_accuracy: 0.8813
#
# Epoch 00031: val_loss did not improve from 0.23012
# Epoch 32/50
#  - 8s - loss: 0.2878 - accuracy: 0.8907 - val_loss: 0.2155 - val_accuracy: 0.9195
#
# Epoch 00032: val_loss improved from 0.23012 to 0.21551, saving model to model.h5
# Epoch 33/50
#  - 8s - loss: 0.2915 - accuracy: 0.8886 - val_loss: 0.4382 - val_accuracy: 0.7928
#
# Epoch 00033: val_loss did not improve from 0.21551
# Epoch 34/50
#  - 9s - loss: 0.2756 - accuracy: 0.8850 - val_loss: 0.4293 - val_accuracy: 0.7907
#
# Epoch 00034: val_loss did not improve from 0.21551
# Epoch 35/50
#  - 8s - loss: 0.2857 - accuracy: 0.8933 - val_loss: 0.3360 - val_accuracy: 0.8451
#
# Epoch 00035: val_loss did not improve from 0.21551
# Epoch 36/50
#  - 8s - loss: 0.2792 - accuracy: 0.8891 - val_loss: 0.3219 - val_accuracy: 0.8551
#
# Epoch 00036: val_loss did not improve from 0.21551
# Epoch 37/50
#  - 8s - loss: 0.2907 - accuracy: 0.8917 - val_loss: 0.2268 - val_accuracy: 0.9155
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00037: val_loss did not improve from 0.21551
# Epoch 38/50
#  - 8s - loss: 0.3041 - accuracy: 0.8865 - val_loss: 0.2924 - val_accuracy: 0.8592
#
# Epoch 00038: val_loss did not improve from 0.21551
# Epoch 39/50
#  - 8s - loss: 0.2794 - accuracy: 0.8933 - val_loss: 0.1983 - val_accuracy: 0.9256
#
# Epoch 00039: val_loss improved from 0.21551 to 0.19830, saving model to model.h5
# Epoch 40/50
#  - 8s - loss: 0.2958 - accuracy: 0.8850 - val_loss: 0.2074 - val_accuracy: 0.9195
#
# Epoch 00040: val_loss did not improve from 0.19830
# Epoch 41/50
#  - 9s - loss: 0.2780 - accuracy: 0.8980 - val_loss: 0.2310 - val_accuracy: 0.8974
#
# Epoch 00041: val_loss did not improve from 0.19830
# Epoch 42/50
#  - 8s - loss: 0.2845 - accuracy: 0.8891 - val_loss: 0.2112 - val_accuracy: 0.9175
#
# Epoch 00042: val_loss did not improve from 0.19830
# Epoch 43/50
#  - 8s - loss: 0.2741 - accuracy: 0.8957 - val_loss: 0.3976 - val_accuracy: 0.8229
#
# Epoch 00043: val_loss did not improve from 0.19830
# Epoch 44/50
#  - 8s - loss: 0.2653 - accuracy: 0.9047 - val_loss: 0.2164 - val_accuracy: 0.9135
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00044: val_loss did not improve from 0.19830
# Epoch 45/50
#  - 8s - loss: 0.2960 - accuracy: 0.8918 - val_loss: 0.1995 - val_accuracy: 0.9215
#
# Epoch 00045: val_loss did not improve from 0.19830
# Epoch 46/50
#  - 8s - loss: 0.2550 - accuracy: 0.8987 - val_loss: 0.1939 - val_accuracy: 0.9235
#
# Epoch 00046: val_loss improved from 0.19830 to 0.19387, saving model to model.h5
# Epoch 47/50
#  - 8s - loss: 0.2797 - accuracy: 0.9064 - val_loss: 0.2458 - val_accuracy: 0.9014
#
# Epoch 00047: val_loss did not improve from 0.19387
# Epoch 48/50
#  - 9s - loss: 0.2738 - accuracy: 0.9058 - val_loss: 0.2117 - val_accuracy: 0.9215
#
# Epoch 00048: val_loss did not improve from 0.19387
# Epoch 49/50
#  - 8s - loss: 0.2527 - accuracy: 0.9073 - val_loss: 0.2154 - val_accuracy: 0.9175
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00049: val_loss did not improve from 0.19387
# Epoch 50/50
#  - 8s - loss: 0.2523 - accuracy: 0.9062 - val_loss: 0.2068 - val_accuracy: 0.9235
#
# Epoch 00050: val_loss did not improve from 0.19387

# %% [markdown]
# ## Final Loss and Accuracy

# %%
#model = load_model('../output/kaggle/working/model.h5')
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 497/497 [==============================] - 1s 2ms/step
# Final Loss: 0.20675026198148247, Final Accuracy: 0.923541247844696

# %% [markdown]
# ## Confusion Matrix

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')

# %% [markdown]
# ## Accuracy and Loss Curve

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Prediction from Image

# %%
from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('/kaggle/input/sarscov2-ctscan-dataset/SARS-Cov-2/COVID/Covid (1010).png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('/kaggle/input/sarscov2-ctscan-dataset/SARS-Cov-2/COVID/Covid (1010).png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [9.9953413e-01 4.6586050e-04]
# Prediction: Covid-19

# %% [markdown]
# ## If you like this notebook please upvote. Thanks
